# %%
//%log:0
//%outputtype:text/html
<H2>this html code</H2>
<hr/>
<H3>this html code</H3>
# Out:
# <H2>this html code</H2>
# <hr/>
# <H3>this html code</H3>

# %%
//%log:0
//%outputtype:text/html
<h2>Norwegian Mountain Trip</h2>
<img border="0" src="data:image/jpeg;base64,..." alt="Pulpit rock" width="304" height="228">
# Out:
# <h2>Norwegian Mountain Trip</h2>
# <img border="0" src="data:image/jpeg;base64,..." alt="Pulpit rock" width="304" height="228">
